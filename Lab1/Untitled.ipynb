# %%
pip install numpy opencv-python scikit-image pillow matplotlib
# Out:
# Requirement already satisfied: numpy in c:\programdata\miniconda3\lib\site-packages (2.4.2)
# Requirement already satisfied: opencv-python in c:\programdata\miniconda3\lib\site-packages (4.13.0.90)
# Requirement already satisfied: scikit-image in c:\programdata\miniconda3\lib\site-packages (0.26.0)
# Requirement already satisfied: pillow in c:\programdata\miniconda3\lib\site-packages (11.3.0)
# Requirement already satisfied: matplotlib in c:\programdata\miniconda3\lib\site-packages (3.10.8)
# Requirement already satisfied: scipy>=1.11.4 in c:\programdata\miniconda3\lib\site-packages (from scikit-image) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in c:\programdata\miniconda3\lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\programdata\miniconda3\lib\site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programdata\miniconda3\lib\site-packages (from scikit-image) (2026.1.28)
# Requirement already satisfied: packaging>=21 in c:\programdata\miniconda3\lib\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\programdata\miniconda3\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\miniconda3\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\miniconda3\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\miniconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
img = cv2.imread('cameraman.tif')

# %%
plt.imshow(img)
plt.show()

# %%
img2 = Image.open('f14.tif')

# %%
plt.imshow(img2, cmap=cm.Greys_r)
plt.show()

# %%
cv2.imwrite('new_image.jpg', img)
# Out:
# True

# %%
img2.save('new_image2.jpg')

# %%
print(img.shape)
print(img)
# Out:
# (256, 256, 3)
# [[[156 156 156]
#   [159 159 159]
#   [158 158 158]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [152 152 152]]
#
#  [[160 160 160]
#   [154 154 154]
#   [157 157 157]
#   ...
#   [154 154 154]
#   [155 155 155]
#   [153 153 153]]
#
#  [[156 156 156]
#   [159 159 159]
#   [158 158 158]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [152 152 152]]
#
#  ...
#
#  [[114 114 114]
#   [132 132 132]
#   [123 123 123]
#   ...
#   [135 135 135]
#   [137 137 137]
#   [114 114 114]]
#
#  [[121 121 121]
#   [126 126 126]
#   [130 130 130]
#   ...
#   [133 133 133]
#   [130 130 130]
#   [113 113 113]]
#
#  [[121 121 121]
#   [126 126 126]
#   [130 130 130]
#   ...
#   [133 133 133]
#   [130 130 130]
#   [113 113 113]]]

# %%
img_array = np.array(img2)
print(img_array.shape)
print(img_array)
# Out:
# (480, 640)
# [[164 164 162 ... 198 200 197]
#  [161 165 165 ... 198 199 198]
#  [164 166 163 ... 198 197 199]
#  ...
#  [199 196 192 ... 208 206 204]
#  [196 192 189 ... 207 210 208]
#  [189 191 187 ... 201 204 204]]
